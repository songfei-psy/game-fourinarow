# %%
# List saved block files from data folders (mode-selectable)
import os, glob, json
import numpy as np
import pandas as pd

# Notebook is at repo root; data is under ./data
repo_root = os.getcwd()
data_dir = os.path.join(repo_root, 'data')

# Mode selection: 'pve' (default) or 'pvp'
mode_select = 'pve'  # change to 'pvp' if needed
mode_dir = os.path.join(data_dir, mode_select)

# Collect block-json files (saved by play_game.py) for selected mode only
def list_block_files_for_mode(mode_dir, mode_select):
    files = []
    if os.path.isdir(mode_dir):
        for path in sorted(glob.glob(os.path.join(mode_dir, f"{mode_select}-blocks-*.json"))):
            files.append((mode_select, path))
    return files

files = list_block_files_for_mode(mode_dir, mode_select)
print(f"Mode: {mode_select}. Found {len(files)} block files:")
for i, (mode, path) in enumerate(files):
    print(f"[{i}] {mode} :: {os.path.basename(path)}")

# Choose which file and player to fit
file_idx = 0   # set target file index here
player_select = 2  # 1 for player1, 2 for player2 (default 2)

if not files:
    raise RuntimeError(f"No block files found under data/{mode_select}.")
mode, selected_path = files[file_idx]
print(f"\nSelected: [{file_idx}] {mode} :: {os.path.basename(selected_path)}")

# Load selected block JSON
with open(selected_path, 'r') as f:
    block_json = json.load(f)

player_key = 'player2' if player_select == 2 else 'player1'
blk = block_json[player_key]

env_pid = blk.get('env_player_id', [])
trials = blk.get('trial', [])
if not env_pid or len(env_pid) != len(trials):
    env_pid = [player_select - 1] * len(trials)  # fallback: use selected player id (0/1)

# Build subdata DataFrame for the chosen player
subdata = pd.DataFrame({
    'trial': trials,
    'board_idx': blk.get('board_idx', []),
    'action_idx': blk.get('action_idx', []),
    'time_elapsed': blk.get('time_elapsed', []),
    'rt': blk.get('rt', []),
    'env_player_id': env_pid
})
print(subdata.head())

# Extract design & response sequences for fitting
board_arr = np.array(subdata['board_idx'], dtype=int)
resp_arr = np.array(subdata['action_idx'], dtype=int)
player_arr = np.array(subdata['env_player_id'], dtype=int)
design = np.stack([board_arr, player_arr], axis=1)
response = resp_arr
print(f"design shape: {design.shape}, response length: {len(response)}")
# Out:
# Mode: pve. Found 1 block files:
# [0] pve :: pve-blocks-2025-12-24_18-05-27.json
#
# Selected: [0] pve :: pve-blocks-2025-12-24_18-05-27.json
#    trial        board_idx  action_idx  time_elapsed        rt  env_player_id
# 0      1      31381059609          23      1.155936  0.452100              1
# 1      3      31386905460          15      3.464790  1.096701              1
# 2      5     132503653089          31      7.277315  1.056190              1
# 3      7   23009296108212          30      9.058379  0.441688              1
# 4      9  228900428203347          29     15.765532  0.377894              1
# design shape: (6, 2), response length: 6

# %%
import sys, time
from pybads import BADS
from env.agent import *
from env.chess import *
from utils.nnl import IBS
import numpy as np
import pandas as pd

# Reproducibility for sampling-based objective
np.random.seed(42)

# Instantiate model and environment
model = BFSAgent(four_in_a_row())

# Show true/default parameters for reference
true_params = default_params().to_list()
print("True (default_params):", np.round(true_params, 5).tolist())

# Set up IBS objective
ibs = IBS(
            model.response_generator,
            response,
            design, 
            vectorized=True,
            acceleration=1.5,
            num_samples_per_call=0,
            max_iter=10000,
            max_time=np.inf,
        )

# Progress logging wrapper around objective
progress_log = []  # will store dicts: {eval, neg_logl, params, elapsed}
state_best = {"f": np.inf, "x": None}
state_ctr = {"n": 0}

param_names = getattr(model, 'p_names', [f"p{i}" for i in range(len(true_params))])

def target_logged(para: np.ndarray):
    t0 = time.time()
    f = ibs(para, num_reps=20)
    dt = time.time() - t0

    # update counters and best-so-far
    state_ctr["n"] += 1
    k = state_ctr["n"]
    progress_log.append({
        "eval": k,
        "neg_logl": float(f),
        "elapsed": float(dt),
        "params": np.array(para, dtype=float).tolist()
    })
    if f < state_best["f"]:
        state_best["f"] = float(f)
        state_best["x"] = np.array(para, dtype=float).copy()
        flag = "*"  # mark improvement
    else:
        flag = " "

    # brief live print of progress
    print(f"[{k:04d}]{flag} NLL={f:10.3f} | time={dt:6.2f}s | params[:3]={np.round(para[:3],4)} ...")
    return f

# Fit model using BADS
lb = np.array([b[0] for b in model.p_bnds])
ub = np.array([b[1] for b in model.p_bnds])
plb = np.array([b[0] for b in model.p_pbnds])
pub = np.array([b[1] for b in model.p_pbnds])
para0 = plb + np.random.rand(model.n_params) * (pub - plb)

bads_opt = {
    'uncertainty_handling': True,
    'noise_final_samples': 0,
    # keep BADS quiet; we print our own progress
    'display': 'off',
}

bads_ibs = BADS(
    target_logged,
    para0,
    lb,
    ub,
    plb,
    pub,
    options=bads_opt
)

# Run the optimization (prints happen during objective calls)
theta_ibs = bads_ibs.optimize()

# Summaries after finish
print("\n=== Optimization Summary ===")
print(f"Evaluations: {state_ctr['n']}")
print("Best NLL:", round(state_best["f"], 5))
if state_best["x"] is not None:
    best_arr = state_best["x"].astype(float)
    diff = best_arr - np.array(true_params, dtype=float)
    print("Best params:")
    for i, (name, v, t, d) in enumerate(zip(param_names, best_arr, true_params, diff)):
        print(f"  {i:02d} {name:>8}: est={v: .5f} | true={t: .5f} | Δ={d: .5f}")

# Make a compact DataFrame for inspection (without huge param arrays expanded)
prog_df = pd.DataFrame([
    {"eval": r["eval"], "neg_logl": r["neg_logl"], "elapsed": r["elapsed"]}
    for r in progress_log
])
print("\nProgress (last 10):")
print(prog_df.tail(10))
# Out:
# True (default_params): [0.02, 0.02, 2.0, 0.005, 0.92498, 0.60913, 0.90444, 0.45076, 3.4272, 20.1728]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 88
#      77 bads_ibs = BADS(
#      78     target_logged,
#      79     para0,
#    (...)
#      84     options=bads_opt
#      85 )
#      87 # Run the optimization (prints happen during objective calls)
# ---> 88 theta_ibs = bads_ibs.optimize()
#      90 # Summaries after finish
#      91 print("\n=== Optimization Summary ===")
#
# File ~/Applications/anaconda3/envs/planning/lib/python3.10/site-packages/pybads/bads/bads.py:1170, in BADS.optimize(self)
#    1167 self.restarts = self.options["restarts"]
#    1169 # Initialize gp
# -> 1170 gp, Ns_gp, sn2hpd, hyp_dict = self._init_optimization_()
#    1172 self.search_es_hedge = None  # init search hedge to None
#    1174 if self.options["output_fcn"] is not None:
#
# File ~/Applications/anaconda3/envs/planning/lib/python3.10/site-packages/pybads/bads/bads.py:1052, in BADS._init_optimization_(self)
#    1049 self.optim_state["random_seed"] = self._init_random_seed_()
#    1051 # Evaluate starting point and initial mesh,
# -> 1052 self._init_mesh_()
#    1054 # Change options for uncertainty handling
#    1055 if self.optim_state["uncertainty_handling_level"] > 0:
#
# File ~/Applications/anaconda3/envs/planning/lib/python3.10/site-packages/pybads/bads/bads.py:924, in BADS._init_mesh_(self)
#     918 """
#     919 A private function to initialize the mesh frame and the optimization problem.
#     920 It evaluates the initial points, which includes the starting point and the generated point retrieved from a sobol sequence generating method.
#     921 The init_mesh also assess if the target function is stochastic and set the parameter of BADS for handling stochastic targets.
#     922 """
#     923 # Evaluate starting point and initial mesh, determine if function is noisy
# --> 924 self.yval, self.fsd, _ = self.function_logger(self.u)
#     925 if self.fsd is None:
#     926     self.fsd = np.nan
#
# File ~/Applications/anaconda3/envs/planning/lib/python3.10/site-packages/pybads/function_logger/function_logger.py:120, in FunctionLogger.__call__(self, x, record_duplicate_data)
#     118 try:
#     119     timer.start_timer("funtime")
# --> 120     fun_res = self.fun(x_orig)
#     121     timer.stop_timer("funtime")
#     122     if self.he_noise_flag:
#
# Cell In[3], line 40, in target_logged(para)
#      38 def target_logged(para: np.ndarray):
#      39     t0 = time.time()
# ---> 40     f = ibs(para, num_reps=20)
#      41     dt = time.time() - t0
#      43     # update counters and best-so-far
#
# File ~/Study/gitclone/game-fourinarow/utils/nnl.py:714, in IBS.__call__(self, params, num_reps, trial_weights, additional_output, return_positive)
#     697         neg_logl = -neg_logl
#     698     return (
#     699         neg_logl,
#     700         K,
#    (...)
#     704         exit_flag,
#     705     )
#     707 (
#     708     neg_logl,
#     709     K,
#     710     num_reps_per_trial,
#     711     num_samples_total,
#     712     fun_count,
#     713     exit_flag,
# --> 714 ) = compute_logl(self, params, num_reps, weights, return_positive, t0)
#     716 if additional_output in [None, "none"]:
#     717     return neg_logl
#
# File ~/Study/gitclone/game-fourinarow/utils/nnl.py:682, in IBS.__call__.<locals>.compute_logl(self, params, num_reps, weights, return_positive, t0)
#     665     return (
#     666         neg_logl,
#     667         K,
#    (...)
#     671         exit_flag,
#     672     )
#     674 if vectorized_flag:
#     675     (
#     676         neg_logl,
#     677         K,
#     678         num_reps_per_trial,
#     679         num_samples_total,
#     680         fun_count,
#     681         exit_flag,
# --> 682     ) = vectorized_ibs_sampling(
#     683         params, simulated_data, elapsed_time, t0, num_reps
#     684     )
#     685 else:
#     686     (
#     687         neg_logl,
#     688         K,
#    (...)
#     692         exit_flag,
#     693     ) = loop_ibs_sampling(params, simulated_data, t0, num_reps)
#
# File ~/Study/gitclone/game-fourinarow/utils/nnl.py:341, in IBS.__call__.<locals>.compute_logl.<locals>.vectorized_ibs_sampling(params, simulated_data0, elapsed_time0, t0, num_reps)
#     337     simulated_data = self.sample_from_model(
#     338         params, T_matrix.reshape(-1)
#     339     )
#     340 else:
# --> 341     simulated_data = self.sample_from_model(
#     342         params,
#     343         self.design_matrix[T_matrix.reshape(-1)],
#     344     )
#     345 fun_count += 1
#     346 elapsed_time = time.time() - start
#
# File ~/Study/gitclone/game-fourinarow/env/agent.py:97, in basic_agent.response_generator(self, params, design)
#      95 # design can be an array of state indices or rows [board_idx, player_id]
#      96 state_lst = [self.env.embed(d) for d in design]
# ---> 97 action_lst = list(map(self.get_action, state_lst))  # responses from the agent (true actions)
#      98 return np.array([self.env.action2idx(action) for action in action_lst])
#
# File ~/Study/gitclone/game-fourinarow/env/agent.py:718, in BFSAgent.get_action(self, state)
#     717 def get_action(self, state):
# --> 718     root = self.plan(state)
#     719     action = self.minmax(root).action
#     720     return (int(action[0]), int(action[1]))
#
# File ~/Study/gitclone/game-fourinarow/env/agent.py:760, in BFSAgent.plan(self, state)
#     758 node = self.select_node(root)
#     759 # check if the state is terminated
# --> 760 self.expand_node(node)
#     761 # backpropagate the value
#     762 self.backpropagate(node)
#
# File ~/Study/gitclone/game-fourinarow/env/agent.py:180, in HeuristicAgent.expand_node(self, node)
#     174 for action in valid_actions:  # expand all valid actions, means all possible nodes without pruning
#     175     # this deepcopy is important
#     176     # as the transit function will modify the state
#     177     # we need to keep the original state for the parent node
#     178     # otherwise, the state will be modified
#     179     state_next, _, done, info = self.env.transit(deepcopy(state), action)
# --> 180     child_node = Node(
#     181         state=state_next,
#     182         action=action,
#     183         parent=node,  # set the parent node, the input node
#     184         heuristic_fn=self.heuristic,
#     185         depth=node.depth + 1  # increment depth in each loop
#     186     )
#     187     node.children.append(child_node)  # add child node to the parent node
#     188 # get the max value of the children
#
# File ~/Study/gitclone/game-fourinarow/env/agent.py:47, in Node.__init__(self, state, action, parent, depth, value, heuristic_fn)
#      45 self.parent = parent
#      46 self.children = []
# ---> 47 self.value = heuristic_fn(state) if heuristic_fn is not None else 0
#      48 self.depth = depth
#
# File ~/Study/gitclone/game-fourinarow/env/agent.py:290, in HeuristicAgent.heuristic(self, state, verbose)
#     288 if verbose: print('\n unconnected 2-in-a-row:')
#     289 if verbose: print('player:')
# --> 290 f_u2_player = self.get_unconnected_2_feature(board, player_pieces, verbose=verbose)
#     291 if verbose: print('opponent:')
#     292 f_u2_opponent = self.get_unconnected_2_feature(board, opponent_pieces, verbose=verbose)
#
# File ~/Study/gitclone/game-fourinarow/env/agent.py:515, in HeuristicAgent.get_unconnected_2_feature(board, player_pieces, not_occupied, verbose)
#     510 pattern = None
#     512 # Check x-x- pattern
#     513 if (next_valid and next2_valid and
#     514         board[next_r, next_c] == not_occupied and
# --> 515         (next2_r, next2_c) in piece_set and
#     516         (next3_valid and board[next3_r, next3_c] == not_occupied) and
#     517         (not prev_valid or board[prev_r, prev_c] != player_color)):
#     518     feature_key = (r, c, dr, dc)
#     519     pattern = "x-x-"
#
# KeyboardInterrupt:

# %%
# Inspect and visualize parameter evolution (optional to run after fitting)
import numpy as np
import pandas as pd

if 'progress_log' in globals() and len(progress_log) > 0:
    df = pd.DataFrame(progress_log)
    # expand params into separate columns
    P = pd.DataFrame(df['params'].tolist())
    if 'param_names' in globals() and len(param_names) == P.shape[1]:
        P.columns = param_names
    else:
        P.columns = [f"p{i}" for i in range(P.shape[1])]
    df = pd.concat([df.drop(columns=['params']), P], axis=1)
    df['cum_best'] = df['neg_logl'].cummin()

    print("Rows:", len(df))
    print(df[['eval','neg_logl','cum_best'] + list(P.columns)].tail(10))

    # Uncomment to plot evolution (can be noisy/slow)
    # import matplotlib.pyplot as plt
    # fig, axes = plt.subplots(1, 2, figsize=(12,4))
    # axes[0].plot(df['eval'], df['neg_logl'], label='neg_logl')
    # axes[0].plot(df['eval'], df['cum_best'], label='cum_best')
    # axes[0].set_xlabel('eval')
    # axes[0].set_ylabel('neg_logl')
    # axes[0].legend()
    # for name in P.columns:
    #     axes[1].plot(df['eval'], df[name], label=name, alpha=0.7)
    # if 'true_params' in globals():
    #     for j, name in enumerate(P.columns):
    #         axes[1].axhline(true_params[j], color='k', lw=0.5, alpha=0.3)
    # axes[1].set_xlabel('eval')
    # axes[1].set_ylabel('param value')
    # axes[1].legend(ncol=2, fontsize=8)
    # plt.tight_layout()
else:
    print("progress_log is empty; run the fitting cell first.")
